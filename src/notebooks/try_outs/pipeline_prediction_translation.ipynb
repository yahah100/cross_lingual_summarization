# %%
import tensorflow as tf
import torch

import pandas as pd
from pathlib import Path
import time

from rouge_score import rouge_scorer
from rouge_score import scoring

from spacy.lang.en import English
from spacy.lang.de import German

# %%
if not tf.config.list_physical_devices('GPU'):
    print("Change runtime to \"GPU runtime\" for faster computations")

# %%
BATCH_SIZE = 8

SHUFFEL_SIZE = 1024

learning_rate = 3e-5

model_size = "t5-base"

MAX_ARTICLE_LEN = 512

MAX_HIGHLIGHT_LEN = 150

# %%
# tokenizer = T5Tokenizer.from_pretrained(model_size)
# model = TFT5ForConditionalGeneration.from_pretrained(model_size)

# task_specific_params = model.config.task_specific_params
# if task_specific_params is not None:
#     model.config.update(task_specific_params.get("summarization", {}))
    
# pad_token_id = tokenizer.pad_token_id

# %%
# val_loss = tf.keras.metrics.Mean(name='val_loss')
# val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy')

# model.summary()

# %%
# ckpt_file = "../models/checkpoint_cross_lingual.ckpt"
# model.load_weights(ckpt_file)

# %% [markdown]
# ## Pipeline Summarize Then Translate (SumTrans)
# both with english and german

# %%
data_points = []
filname = "../results/t5_cross_lingual_result.txt"
file = open(filname, "r")
for line in file:
    data_points.append(line)

# %%
class SummaryData():
    
    def __init__(self):
        self.id = -1
        self.item_id = -1
        self.language_tag = ''
        self.real_data = ''
        self.pred_data = ''  
        self.translated = ''
        self.translated_real = ''

# %%
count = 0
id_count = 0
item_id_count = 1
summary_data = SummaryData()
summary_data_list = []
for point in data_points:
    count += 1
    
    if count == 1:
        summary_data.language_tag = point.split(" ")[2]
        summary_data.id = id_count
        summary_data.item_id =  item_id_count
        if (item_id_count % 8) == 0 and summary_data.language_tag != "en_to_en":
            item_id_count -= 7
        else:
#             print(item_id_count, summary_data.language_tag)
            item_id_count += 1
            
        id_count += 1
    elif count == 3:
        summary_data.pred_data = ": ".join(point.split(": ")[1:])
    elif count == 5:
        summary_data.real_data = ": ".join(point.split(": ")[1:])
        summary_data_list.append(summary_data)
        summary_data = SummaryData()
        count = 0
summary_data_list[0].__dict__, summary_data_list[1].__dict__
# Out:
# ({'id': 0,
#   'item_id': 1,
#   'language_tag': 'ger_to_ger',
#   'real_data': 'Beatrice sah Rennen auf der Terrasse mit dem Kronprinzen des Golfstaates. Mark 13. Urlaub seit November letzten Jahres, und vierte in einem Monat. Prinzessin kündigte ihren Job bei Sony Pictures in New York vor Weihnachten. Trotzdem wird sie als Vollzeit-Arbeiterin auf der Website ihres Vaters beschrieben.\n',
#   'pred_data': 'Prinzessin Beatrice wurde beim Großen Preis von Bahrain gesehen. Die 26-Jährige war mit ihrem langjährigen Freund Dave Clark im Golfstaat gesichtet. Beatrice befand sich in der Startaufstellung hinter dem Kronprinzen von Bahrain. Es wird vermutet, dass auch Formel-1-Legende Sir Jackie Stewart und Komiker Rory Bremner im Turm waren.\n',
#   'translated': '',
#   'translated_real': ''},
#  {'id': 1,
#   'item_id': 2,
#   'language_tag': 'ger_to_ger',
#   'real_data': 'Nach Angaben des türkischen Militärs wurden bei der Flucht vier türkische Soldaten verletzt. Der türkische Präsident Recep Tayyip Erdogan sagt, Zusammenstöße seien der Versuch, einen Lösungsprozess mit den Kurden zu stoppen. Die Gewalt zwischen Kurden und dem türkischen Militär dauert seit mehr als drei Jahrzehnten an.\n',
#   'pred_data': 'Fünf Kämpfer der Arbeiterpartei Kurdistans wurden bei Zusammenstößen mit türkischen Streitkräften getötet und ein weiterer verletzt, teilt das Militär des Landes mit. Die kurdischen Separatisten eröffneten das Feuer aus großer Entfernung auf Türkische Soldaten, die ein Gebiet in Agri sicherten.\n',
#   'translated': '',
#   'translated_real': ''})

# %%
ger_to_ger_results = list(filter(lambda data: data.language_tag == "ger_to_ger" ,summary_data_list))
ger_to_en_results = list(filter(lambda data: data.language_tag == "ger_to_en" ,summary_data_list))

en_to_en_results = list(filter(lambda data: data.language_tag == "en_to_en" ,summary_data_list))
en_to_ger_results = list(filter(lambda data: data.language_tag == "en_to_ger" ,summary_data_list))

assert len(ger_to_en_results) == len(ger_to_ger_results) == len(en_to_en_results) == len(en_to_ger_results)

ger_to_ger_results[3].__dict__
# Out:
# {'id': 3,
#  'item_id': 4,
#  'language_tag': 'ger_to_ger',
#  'real_data': 'Kim Callaghan, aus Irland, häufte die Pfunde nach dem Kinderkriegen an. Beschränkt auf Kleidungsgröße 28 sorgte sich Kim, 39, dass sie einem Mann ähnelte. Sie trat der Schlankheitskur bei und ließ zehn Kleidergrößen sowie den 10. Platz fallen.\n',
#  'pred_data': 'Kim Callaghan, 39, häufte nach der Geburt ihrer beiden Kinder die Pfunde an und erreichte einen besorgniserregenden 20st 3lb. Nach sportlicher Betätigung und dem Tausch stärkehaltiger Mahlzeiten gegen kleinere Portionen auf ein schlankes Maß geschrumpft. Bevor sie ihre Kleiderschrank verschlankte, beschränkte sie sich auf Kleidungsstücke in Größe 28.\n',
#  'translated': '',
#  'translated_real': ''}

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
nlp_en = English()
nlp_ger = German()


sentencizer = nlp_en.create_pipe("sentencizer")
nlp_en.add_pipe(sentencizer)
nlp_ger.add_pipe(sentencizer)


doc_en = nlp_en("This is a sentence. This is another sentence.")
doc_ger = nlp_ger("Das ist ein Satz. Das ist ein weiterer Satz.")
list(doc_en.sents), list(doc_ger.sents)
# Out:
# ([This is a sentence., This is another sentence.],
#  [Das ist ein Satz., Das ist ein weiterer Satz.])

# %%
class MyDatasetGerman(torch.utils.data.Dataset):
    def __init__(self, text):
        self.x = text
        
    def __getitem__(self, index):
        return self.x[index].id, list(nlp_ger(self.x[index].pred_data).sents)
    
    def __len__(self):
        return len(self.x)
    
class MyDatasetEnglish(torch.utils.data.Dataset):
    def __init__(self, text):
        self.x = text
        
    def __getitem__(self, index):
        return self.x[index].id, list(nlp_en(self.x[index].pred_data).sents)
    
    def __len__(self):
        return len(self.x)

# %%
ger_data = MyDatasetGerman(ger_to_ger_results)
en_data = MyDatasetEnglish(en_to_en_results)
en_data[0]
# Out:
# (24,
#  [Princess Beatrice spotted at Bahrain Grand Prix with long-term boyfriend Dave Clark .,
#   Onlooker said 26-year-old was walking behind the Crown Prince of Bahrain .,
#   Princes regime accused of violently repressing pro-democracy protests .,
#   Sir Jackie Stewart and comedian Rory Bremner watched race from the tower .,
#   ])

# %% [markdown]
# ## Use Fairseq Model

# %%
# Load an En-De Transformer model trained on WMT'19 data:
en2de = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.en-de.single_model', tokenizer='moses', bpe='fastbpe')
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_fairseq_master

# %%
# Access the underlying TransformerModel
assert isinstance(en2de.models[0], torch.nn.Module)

# Translate from En-De
de = en2de.translate('PyTorch Hub is a pre-trained model repository designed to facilitate research reproducibility.')
assert de == 'PyTorch Hub ist ein vorgefertigtes Modell-Repository, das die Reproduzierbarkeit der Forschung erleichtern soll.'

# to gpu
en2de = en2de.to(device)

# %%
result_list = []
for i, data in en_data:
    predictions = en2de.translate(data)
    result_list.append({'id':i, 'translated':predictions})
print(result_list[:])
# Out:
# [{'id': 24, 'translated': ['Prinzessin Beatrice beim Großen Preis von Bahrain mit ihrem langjährigen Freund Dave Clark.', 'Beobachter sagten, der 26-Jährige sei hinter dem Kronprinzen von Bahrain hergelaufen.', 'Prinzen-Regime beschuldigt, prodemokratische Proteste gewaltsam zu unterdrücken.', 'Sir Jackie Stewart und Komiker Rory Bremner verfolgten das Rennen vom Tower aus.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 25, 'translated': ['Kurdische Separatisten eröffnen aus großer Entfernung das Feuer und nehmen türkische Soldaten ins Visier, berichtet CNN Türk.', 'Der türkische Ministerpräsident Ahmet Davutoglu sagt: "Die angemessene Antwort auf den abscheulichen Anschlag in Agri wird gegeben". Auch der türkische Präsident Recep Tayyip Erdogan verurteilt die Gewalt scharf.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 26, 'translated': ['Random Darknet Shopper kaufte eine Reihe von Artikeln zum Verkauf im Deep Web.', 'Es würde bis zu $100 pro Woche ausgeben, indem es zufällig einen Artikel kauft.', 'Der Roboter würde dann seinen Kauf per Post an eine Gruppe von Künstlern verschicken.', 'Anschließend stellten sie die Gegenstände in einer Ausstellung im schweizerischen St. Gallen aus.', 'Die Polizei beschlagnahmte die Drogen, den Computer und den Rest der darin befindlichen Gegenstände.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 27, 'translated': ['Kim Callaghan, 39, häufte nach der Geburt ihrer beiden Kinder die Pfunde an.', 'Sie erreichte einen besorgniserregenden 20st 3lb und war besorgt, dass ihre Größe dazu führte, dass sie wie ein Mann aussah.', 'Die zweifache Mutter machte eine dramatische Diät, bei der sie die Hälfte ihres Körpergewichts verlor.', 'Kim ist inzwischen auf schlanke Größe acht geschrumpft.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 28, 'translated': ['Danny Willett schrie einen Beamten außerhalb der Tribüne lautstark an.', 'Der 27-Jährige war noch sichtlich verärgert, als er nach einem Bogey das Grün verließ.', 'Er sagte, er habe sich beruhigt, als er etwa 30 Minuten später mit Reportern sprach, nachdem er eine Eins-unter-71-Karte gezogen hatte.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 29, 'translated': ['Feedback-Autorin und Marathonläuferin Lucy Waterlow testete die Trainer.', 'Die adidas Ultra Boost Turnschuhe für 130 £kommen bei Aldi für 19,99 £in den Handel.', 'Sie verfügen über ihre viel gepriesene Boost-Dämpfungstechnologie.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 30, 'translated': ['Jack Wilshere, Mikel Arteta und Abou Diaby starten allesamt für die U21 des FC Arsenal.', 'Die Gunners treffen am Dienstagabend im Emirates Stadium auf Stoke City.', 'Auch Flügelspieler Serge Gnabry steht in der Startformation.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 31, 'translated': ['Sechs Männer müssen insgesamt 31 Jahre ins Gefängnis, nachdem sie wegen einer Reihe von Sexualdelikten an Jugendlichen verurteilt wurden.', 'Die Delikte, die von Anstiftung zu sexuellen Handlungen mit einem Kind bis hin zu Vergewaltigungen reichten, ereigneten sich in Autos, Wäldern oder in den Wohnungen der Angeklagten in Banbury, Oxfordshire.', 'Ahmed Hassan-Sule, 21, und Mohamed Saleh, 20, wurden im März schuldig gesprochen und zu Haftstrafen zwischen drei und neun Jahren verurteilt.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 56, 'translated': ['Die US-Regierung und die American Heart Association warnen, dass zu viel Salz jedes Jahr zum Tod Zehntausender Amerikaner beiträgt.', 'Die Richtlinien schreiben derzeit vor, dass die Menschen ihre Aufnahme auf 2.300 Milligramm beschränken sollten, wobei ein noch strengerer Grenzwert für Afroamerikaner und Menschen über 50 gilt.', 'Salzskeptiker glauben jedoch, dass es den meisten Amerikanern gut geht.', 'Es geht um die Frage, wer die Verantwortung trägt.']}, {'id': 57, 'translated': ['Überwachungsaufnahmen zeigen, wie  ...

# %%
for i in range(len(result_list)):
    assert en_to_en_results[i].id == result_list[i]['id']
    en_to_en_results[i].translated = "".join(result_list[i]['translated'])
    en_to_en_results[i].translated_real = en_to_ger_results[i].real_data
    assert en_to_en_results[i].item_id == en_to_ger_results[i].item_id
    
en_to_en_results[11].__dict__
# Out:
# {'id': 59,
#  'item_id': 12,
#  'language_tag': 'en_to_en',
#  'real_data': 'Experts question if packed out planes are putting passengers at risk . U.S consumer advisory group says minimum space must be stipulated . Safety tests conducted on planes with more leg room than airlines offer .\n',
#  'pred_data': 'Tests conducted by the FAA use planes with a 31 inch pitch between each row of seats, a standard which on some airlines has decreased . British Airways has a seat pitch of 31 inches, while easyJet has 29 inches, Thomsons short haul seat pitch is 28 inches, and Virgin Atlantics is 30-31 .\n',
#  'translated': 'Bei den von der FAA durchgeführten Tests werden Flugzeuge mit einem Abstand von 31 Zoll zwischen jeder Sitzreihe verwendet, ein Standard, der bei einigen Fluggesellschaften abgenommen hat.British Airways hat einen Sitzabstand von 31 Zoll, während easyJet 29 Zoll, Thomsons Kurzstreckensitzabstand 28 Zoll und Virgin Atlantics 30-31 Zoll hat.Es geht um die Frage, wer die Verantwortung trägt.',
#  'translated_real': 'Experten bezweifeln, ob überfüllte Flugzeuge Passagiere gefährden. Die US-Verbraucherberatungsgruppe sagt, dass Mindestabstände vorgeschrieben werden müssen. Sicherheitstests in Flugzeugen mit mehr Beinfreiheit als von Fluggesellschaften angeboten, werden durchgeführt.\n'}

# %%
file_name = '../results/en_en_results'
file = open(file_name, "a")
for item in en_to_en_results:
    file.write(str(item.__dict__) + "\n")

# %%
# Load an En-De Transformer model trained on WMT'19 data:
de2en = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.de-en.single_model', tokenizer='moses', bpe='fastbpe').to(device)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_fairseq_master

# %%
result_list_de = []
for i, data in ger_data:
    predictions = de2en.translate(data)
    result_list_de.append({'id':i, 'translated':predictions})
print(result_list_de[:])
# Out:
# [{'id': 0, 'translated': ['Princess Beatrice was seen at the Bahrain Grand Prix.', 'The 26-year-old was spotted in the Gulf state with her longtime boyfriend Dave Clark.', 'Beatrice was on the grid behind the Crown Prince of Bahrain.', 'Formula One legend Sir Jackie Stewart and comedian Rory Bremner are also believed to have been in the tower.', "In fact, it's not."]}, {'id': 1, 'translated': ["Five fighters from the Kurdistan Workers' Party were killed and another wounded in clashes with Turkish forces, the country's military said.", 'Kurdish separatists opened fire from a long distance on Turkish soldiers securing an area in Agri.', "In fact, it's not."]}, {'id': 2, 'translated': ['Random Darknet Shopper bought items that are for sale on the Deep Web.', 'Items included a pair of Nike trainers, fake designer jeans, a scan of a Hungarian passport and a set of British fire keys.', 'The anonymity and encryption of the network has attracted large amounts of illegal activity.', "In fact, it's not."]}, {'id': 3, 'translated': ['Kim Callaghan, 39, piled on the pounds after the birth of her two children and reached a worrying 20st 3lb.', 'Shrunk to a slim size after exercising and swapping starchy meals for smaller portions.', 'Before slimming down her wardrobe, she limited herself to size 28 clothes.']}, {'id': 4, 'translated': ['Danny Willett carded a one-under 71 in his first round on Thursday and the Englishman was left frustrated by a rules official who got out of his way during his round.', 'The 27-year-old said his anger was ignited because the referee knows exactly where to place his buggy.', "In fact, it's not."]}, {'id': 5, 'translated': ['The London Marathon takes place a week on Sunday.', 'The adidas Ultra Boost sneakers are on the market for £130.', 'Email writer and marathon runner Lucy Waterlow tested them before the London Marathon.', "In fact, it's not."]}, {'id': 6, 'translated': ['Jack Wilshere, Mikel Arteta and Abou Diaby start at the Emirates Stadium on Tuesday night.', 'The Gunners face Stoke City in the Premier League on Saturday afternoon.', 'The Grandstand has continued their respective recoveries from injuries.', "In fact, it's not."]}, {'id': 7, 'translated': ['Ahmed Hassan-Sule, 21, was sentenced to nine years in prison.', 'Mohamed Saleh, 22, was jailed for four years and nine months.', 'Girls aged between 13 and 16 were taken by the gang to parties in Banbury, Oxfordshire.', "In fact, it's not."]}, {'id': 32, 'translated': ['The federal government and the American Heart Association have been warning for decades that too much salt contributes to the deaths of tens of thousands of Americans each year.', 'Guidelines currently state that people should limit their intake to 2,300 milligrams.', 'In February, the Advisory Committee on Dietary Guidelines recommended that the higher limit be maintained.', "In fact, it's not."]}, {'id': 33, 'translated': ['Surveillance footage shows 40-year-old Todd Phillips being hit at full speed as he drives down one of his drivers during the first Indy Grand Prix of Louisiana on Sunday.', 'Amazingly, Phillips, from Franklin, Wisconsin, suffered only minor injuries to his leg, which required six stitches.', "It was later reported that he had been mown down by Francesco Dracone's car, which had taken tyres and fuel on lap 25.", "In fact, it's not."]}, {'id': 34, 'translated': ['Christopher Bridger, 25, from Stevenage, Hertfordshire, was jailed for 12 years after being convicted of rape and four other abuse charges.', "In 2008, a jury found him guilty of raping a fellow student while he was training to become a paramedic at St George's University Hospital in London.", "But then, astonishingly, he burst into tears and said: '", "I'm just going to like girls. '", "In fact, it's not."]}, {'id': 35, 'translated': ['Experts say the lack of space on planes is putting our health and safety at risk.', 'DOT and FAA want to set standards for animals on planes, but not minimum human space re ...

# %%
for i in range(len(result_list_de)):
    assert ger_to_ger_results[i].id == result_list_de[i]['id']
    ger_to_ger_results[i].translated = "".join(result_list_de[i]['translated'])
    ger_to_ger_results[i].translated_real = ger_to_en_results[i].real_data
    assert ger_to_ger_results[i].item_id == ger_to_en_results[i].item_id
    
en_to_en_results[11].__dict__
# Out:
# {'id': 59,
#  'item_id': 12,
#  'language_tag': 'en_to_en',
#  'real_data': 'Experts question if packed out planes are putting passengers at risk . U.S consumer advisory group says minimum space must be stipulated . Safety tests conducted on planes with more leg room than airlines offer .\n',
#  'pred_data': 'Tests conducted by the FAA use planes with a 31 inch pitch between each row of seats, a standard which on some airlines has decreased . British Airways has a seat pitch of 31 inches, while easyJet has 29 inches, Thomsons short haul seat pitch is 28 inches, and Virgin Atlantics is 30-31 .\n',
#  'translated': 'Bei den von der FAA durchgeführten Tests werden Flugzeuge mit einem Abstand von 31 Zoll zwischen jeder Sitzreihe verwendet, ein Standard, der bei einigen Fluggesellschaften abgenommen hat.British Airways hat einen Sitzabstand von 31 Zoll, während easyJet 29 Zoll, Thomsons Kurzstreckensitzabstand 28 Zoll und Virgin Atlantics 30-31 Zoll hat.Es geht um die Frage, wer die Verantwortung trägt.',
#  'translated_real': 'Experten bezweifeln, ob überfüllte Flugzeuge Passagiere gefährden. Die US-Verbraucherberatungsgruppe sagt, dass Mindestabstände vorgeschrieben werden müssen. Sicherheitstests in Flugzeugen mit mehr Beinfreiheit als von Fluggesellschaften angeboten, werden durchgeführt.\n'}

# %%
file_name = '../results/ger_ger_results'
file = open(file_name, "a")
for item in ger_to_ger_results:
    file.write(str(item.__dict__) + "\n")
